# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosLTorresULEAM/numpy-pandasIA/blob/main/Jueves_18_07_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/movies.csv')

# %%
df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
df.tail(6)
# Out:
#        movieId                           title                  genres
# 62417   209155      Santosh Subramaniam (2008)   Action|Comedy|Romance
# 62418   209157                       We (2018)                   Drama
# 62419   209159       Window of the Soul (2001)             Documentary
# 62420   209163                Bad Poems (2018)            Comedy|Drama
# 62421   209169             A Girl Thing (2001)      (no genres listed)
# 62422   209171  Women of Devil's Island (1962)  Action|Adventure|Drama

# %%
del df['genres']

# %%
df.tail(6)
# Out:
#        movieId                           title
# 62417   209155      Santosh Subramaniam (2008)
# 62418   209157                       We (2018)
# 62419   209159       Window of the Soul (2001)
# 62420   209163                Bad Poems (2018)
# 62421   209169             A Girl Thing (2001)
# 62422   209171  Women of Devil's Island (1962)

# %%
df.shape
# Out:
# (62423, 2)

# %%
df.columns
# Out:
# Index(['movieId', 'title'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=62423, step=1)

# %%
tmp=df.iloc[255]

# %%
tmp
# Out:
# movieId                                     258
# title      Kid in King Arthur's Court, A (1995)
# Name: 255, dtype: object

# %%
tmp['movieId']
# Out:
# 258

# %%
'movieId' in df.columns
# Out:
# True

# %%
df.iloc[[100,200,300]]
# Out:
#      movieId                 title
# 100      102      Mr. Wrong (1996)
# 200      202  Total Eclipse (1995)
# 300      304      Roommates (1995)

# %%
df.describe()
# Out:
#              movieId
# count   62423.000000
# mean   122220.387646
# std     63264.744844
# min         1.000000
# 25%     82146.500000
# 50%    138022.000000
# 75%    173222.000000
# max    209171.000000

# %%
# prompt: crear 3 variables en cada una guarda valores posteriormente sacamos el valor minimo el maximo y el valor promedio

# Crear 3 variables con valores
variable1 = [10, 20, 30]
variable2 = (5, 15, 25)
variable3 = {1: 5, 2: 10, 3: 15}

# Encontrar el valor mínimo, máximo y promedio de cada variable
min_v1 = min(variable1)
max_v1 = max(variable1)
prom_v1 = sum(variable1) / len(variable1)

min_v2 = min(variable2)
max_v2 = max(variable2)
prom_v2 = sum(variable2) / len(variable2)

min_v3 = min(variable3.values())
max_v3 = max(variable3.values())
prom_v3 = sum(variable3.values()) / len(variable3)

# Imprimir los resultados
print("Variable 1: Minimo =", min_v1, ", Maximo =", max_v1, ", Promedio =", prom_v1)
print("Variable 2: Minimo =", min_v2, ", Maximo =", max_v2, ", Promedio =", prom_v2)
print("Variable 3: Minimo =", min_v3, ", Maximo =", max_v3, ", Promedio =", prom_v3)
# Out:
# Variable 1: Minimo = 10 , Maximo = 30 , Promedio = 20.0
# Variable 2: Minimo = 5 , Maximo = 25 , Promedio = 15.0
# Variable 3: Minimo = 5 , Maximo = 15 , Promedio = 10.0

# %%
movies_df = pd.read_csv('/content/movies.csv')
ratings_df = pd.read_csv('/content/ratings.csv')
tags_df = pd.read_csv('/content/tags.csv')

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating     timestamp
# 0       1    296.0     5.0  1.147880e+09
# 1       1    306.0     3.5  1.147869e+09
# 2       1    307.0     5.0  1.147869e+09
# 3       1    665.0     5.0  1.147879e+09
# 4       1    899.0     3.5  1.147869e+09

# %%
tags_df.head(2) # Use 'tags_df' instead of 'tags'
# Out:
#    userId  movieId      tag   timestamp
# 0       3      260  classic  1439472355
# 1       3      260   sci-fi  1439472256

# %%
del tags_df['timestamp'] # Use 'tags_df' to reference the DataFrame

# %%
print(movies_df.shape)
print(ratings_df.shape)
print(tags_df.shape)
# Out:
# (62423, 3)
# (13042787, 4)
# (1093360, 3)

# %%
import pandas as pd

movies = pd.read_csv('movies.csv')
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags_df.isnull().any() # Use 'tags_df' instead of 'tags'
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
import pandas as pd

ratings_df = pd.read_csv('ratings.csv') # Assuming your ratings data is in 'ratings.csv'
ratings_df.isnull().any()
# Out:
# userId       False
# movieId      False
# rating       False
# timestamp    False
# dtype: bool

# %%
import pandas as pd

tags_df = pd.read_csv('tags.csv') # Assuming your tags data is in 'tags.csv'
tags_df = tags_df.dropna()
tags_df
# Out:
#          userId  movieId                  tag   timestamp
# 0             3      260              classic  1439472355
# 1             3      260               sci-fi  1439472256
# 2             4     1732          dark comedy  1573943598
# 3             4     1732       great dialogue  1573943604
# 4             4     7569     so bad it's good  1573943455
# ...         ...      ...                  ...         ...
# 1093355  162521    66934  Neil Patrick Harris  1427311611
# 1093356  162521   103341     cornetto trilogy  1427311259
# 1093357  162534   189169               comedy  1527518175
# 1093358  162534   189169             disabled  1527518181
# 1093359  162534   189169              robbery  1527518193
#
# [1093344 rows x 4 columns]

# %%
import pandas as pd

tags = pd.read_csv('tags.csv') # Load the tags data from your CSV file
print(tags.shape)
aux1=tags.shape[0]
tags=tags.dropna()
aux2=tags.shape[0]

print(aux1)
print(tags.shape)
print(f'Muestras eliminadas', (aux1 - aux2))
# Out:
# (1093360, 4)
# 1093360
# (1093344, 4)
# Muestras eliminadas 16

# %%
import pandas as pd

ratings = pd.read_csv('ratings.csv') # Load the ratings data, assuming it's in 'ratings.csv'
print(ratings.columns)
print(ratings['rating'].max())
print(ratings['rating'].min())

print("------------------")

cal_alta = ratings[ratings['rating'] >= 4]
cal_alta
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# 5.0
# 0.5
# ------------------
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 5              1     1088     4.0  1147868495
# 8              1     1237     5.0  1147868839
# ...          ...      ...     ...         ...
# 19162173  124329     1690     4.0  1239921025
# 19162174  124329     1721     4.0  1240613763
# 19162177  124329     1732     4.0  1239922403
# 19162178  124329     1748     5.0  1239912175
# 19162183  124329     1968     4.5  1313276050
#
# [9541439 rows x 4 columns]

# %%
import pandas as pd

ratings = pd.read_csv('ratings.csv') # Load the ratings data, assuming it's in 'ratings.csv'
print(ratings.columns)
print(ratings['rating'].max())
print(ratings['rating'].min())

print("------------------")

cal_alta = ratings['rating'] >= 4 # Create a boolean Series
rating_despues = ratings[cal_alta] # Use the boolean Series to filter
print("numero de muestras despues del filtro", rating_despues.shape[0])
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# 5.0
# 0.5
# ------------------
# numero de muestras despues del filtro 11976363
